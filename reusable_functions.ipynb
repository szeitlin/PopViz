# %%
import pandas

# %%
tall = pandas.read_csv("tall_condensed.csv", index_col = 0)

# %%
tall.head()
# Out:
#    index         region     1790     1800     1810     1820     1830     1840  \
# 0      0          Maine   96,540  151,719  228,705  298,335  399,455  501,793
# 1      1  New Hampshire  141,885  183,858  214,460  244,161  269,328  284,574
# 2      2        Vermont   85,425  154,465  217,895  235,981  280,652  291,948
# 3      3  Massachusetts  378,787  422,845  472,040  523,287  610,408  737,699
# 4      4   Rhode Island   68,825   69,122   76,931   83,059   97,199  108,830
#
#       1850
# 0  583,169
# 1  317,976
# 2  314,120
# 3  994,514
# 4  147,545
#
# [5 rows x 9 columns]

# %%
tall = tall.drop(['index'], axis = 1)

# %%
tall.head()
# Out:
#           region     1790     1800     1810     1820     1830     1840  \
# 0          Maine   96,540  151,719  228,705  298,335  399,455  501,793
# 1  New Hampshire  141,885  183,858  214,460  244,161  269,328  284,574
# 2        Vermont   85,425  154,465  217,895  235,981  280,652  291,948
# 3  Massachusetts  378,787  422,845  472,040  523,287  610,408  737,699
# 4   Rhode Island   68,825   69,122   76,931   83,059   97,199  108,830
#
#       1850
# 0  583,169
# 1  317,976
# 2  314,120
# 3  994,514
# 4  147,545
#
# [5 rows x 8 columns]

# %%
region = tall['region']

# %%
state, years1, years2 = 0, [], []

# %%
#for initial testing/debugging
statements = [str(state), str(years1), str(years2)]
print 'state is ' + statements[0], 'years1 is ' + statements[1]+ ' years2 is ' + statements[2]
# Out:
# state is 0 years1 is [] years2 is []

# %%
#state = 0 no column names yet
#state = 1 set of possible column names found
#state = 2 column names check if paired (if match, ignore, if not, change and reset state)


for i in range(len(region)):
    try:
        if state == 1:
            if 'Table' in region[i]:
                years2 = tall.ix[i+1]
                print 'years2 is ' + str(years2.to_string())
                state +=1
        if state == 2:
            if years2[1:8].all() == years1[1:8].all():
                continue
            elif years2[2] != years1[2]:
                print 'years 2 vs. years 1 is ' + str(years2), str(years1)
                chunk = tall[0:i-1] #lop off a piece
                chunk.to_csv("test1.csv")
                             
                newyears = [str(i) for i in years2]
                newyears[0] = 'region'
                tall.columns = [newyears]
                tall = tall[i+2:-1] #return what's left to continue search
                tall.to_csv("tall_chopped.csv")
                            
                years2 = []
                years1 = newyears
                state = 0 
        if state == 0:
            if 'Table' in region[i]:
                years1 = tall.ix[i+1]
                state += 1
            
    except TypeError:
        continue
# Out:
# years 2 vs. years 1 is region     NaN
# 1790      1860
# 1800      1870
# 1810      1880
# 1820      1890
# 1830      1900
# 1840      1910
# 1850      1920
# Name: 26, dtype: object region     NaN
# 1790      1790
# 1800      1800
# 1810      1810
# 1820      1820
# 1830      1830
# 1840      1840
# 1850      1850
# Name: 20, dtype: object
# years 2 vs. years 1 is region     NaN
# 1790      1860
# 1800      1870
# 1810      1880
# 1820      1890
# 1830      1900
# 1840      1910
# 1850      1920
# Name: 26, dtype: object region     NaN
# 1790      1790
# 1800      1800
# 1810      1810
# 1820      1820
# 1830      1830
# 1840      1840
# 1850      1850
# Name: 20, dtype: object
# years 2 vs. years 1 is region     NaN
# 1790      1860
# 1800      1870
# 1810      1880
# 1820      1890
# 1830      1900
# 1840      1910
# 1850      1920
# Name: 26, dtype: object region     NaN
# 1790      1790
# 1800      1800
# 1810      1810
# 1820      1820
# 1830      1830
# 1840      1840
# ...

# %%
chunk.head()
# Out:
#           region     1860     1870     1880     1890     1900     1910  \
# 0          Maine   96,540  151,719  228,705  298,335  399,455  501,793
# 1  New Hampshire  141,885  183,858  214,460  244,161  269,328  284,574
# 2        Vermont   85,425  154,465  217,895  235,981  280,652  291,948
# 3  Massachusetts  378,787  422,845  472,040  523,287  610,408  737,699
# 4   Rhode Island   68,825   69,122   76,931   83,059   97,199  108,830
#
#       1920
# 0  583,169
# 1  317,976
# 2  314,120
# 3  994,514
# 4  147,545
#
# [5 rows x 8 columns]

# %%
shorter = pandas.read_csv("tall_chopped.csv", index_col=0)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-15-dc6776cd5910> in <module>()
# ----> 1 shorter = pandas.read_csv("tall_chopped.csv", index_col=0)
#
# ...

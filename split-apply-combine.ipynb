# %%
import pandas

# %%
tall = pandas.read_csv("tall_condensed.csv")

# %%
tall[35:45]
# Out:
#     Unnamed: 0       region 1790   1800    1810     1820     1830     1840  \
# 35          47  Mississippi  NaN  7,600  31,306   75,448  136,621  375,651
# 36          50     Arkansas  NaN    NaN   1,062   14,273   30,388   97,574
# 37          51    Louisiana  NaN    NaN  76,556  153,407  215,739  352,411
# 38          52     Oklahoma  NaN    NaN     NaN      NaN      NaN      NaN
# 39          53        Texas  NaN    NaN     NaN      NaN      NaN      NaN
# 40          56      Montana  NaN    NaN     NaN      NaN      NaN      NaN
# 41          57        Idaho  NaN    NaN     NaN      NaN      NaN      NaN
# 42          58      Wyoming  NaN    NaN     NaN      NaN      NaN      NaN
# 43          59     Colorado  NaN    NaN     NaN      NaN      NaN      NaN
# 44          60   New Mexico  NaN    NaN     NaN      NaN      NaN      NaN
#
#        1850
# 35  606,526
# 36  209,897
# 37  517,762
# 38      NaN
# 39  212,592
# 40      NaN
# 41      NaN
# 42      NaN
# 43      NaN
# ...

# %%
tall = tall.drop(['Unnamed: 0'], axis=1)

# %%
region = tall['region']

# %%
region[30]
# Out:
# 'Table 1 . U'

# %%
#would like to split up sections
for i in range(len(region)):
    try:
      if 'Table' in region[i]:
         print i
    except TypeError:
         continue
# Out:
# 30
# 54
# 86
# 110
# 142

# %%
'Table' in region[30]
# Out:
# True

# %%
tall[30:32]
# Out:
#          region             1790             1800          1810        1820  \
# 30  Table 1 . U  nited States Re  sident Populati  on by State:  1790 - 185
# 31          NaN             1790             1800          1810        1820
#
#     1830  1840     1850
# 30     0   NaN  (cont.)
# 31  1830  1840     1850
#
# [2 rows x 8 columns]

# %%
tall = tall.drop(tall.index[30:32])

# %%
early = tall[0:51]

# %%
early
# Out:
#             region           1790     1800     1810       1820       1830  \
# 0            Maine         96,540  151,719  228,705    298,335    399,455
# 1    New Hampshire        141,885  183,858  214,460    244,161    269,328
# 2          Vermont         85,425  154,465  217,895    235,981    280,652
# 3    Massachusetts        378,787  422,845  472,040    523,287    610,408
# 4     Rhode Island         68,825   69,122   76,931     83,059     97,199
# 5      Connecticut        237,946  251,002  261,942    275,248    297,675
# 6         New York        340,120  589,051  959,049  1,372,812  1,918,608
# 7       New Jersey        184,139  211,149  245,562    277,575    320,823
# 8     Pennsylvania        434,373  602,365  810,091  1,049,458  1,348,233
# 9             Ohio            NaN   45,365  230,760    581,434    937,903
# 10         Indiana            NaN    5,641   24,520    147,178    343,031
# 11        Illinois            NaN      NaN   12,282     55,211    157,445
# ...

# %%
early = early.dropna(thresh=7)

# %%
early
# Out:
#             region           1790     1800     1810       1820       1830  \
# 0            Maine         96,540  151,719  228,705    298,335    399,455
# 1    New Hampshire        141,885  183,858  214,460    244,161    269,328
# 2          Vermont         85,425  154,465  217,895    235,981    280,652
# 3    Massachusetts        378,787  422,845  472,040    523,287    610,408
# 4     Rhode Island         68,825   69,122   76,931     83,059     97,199
# 5      Connecticut        237,946  251,002  261,942    275,248    297,675
# 6         New York        340,120  589,051  959,049  1,372,812  1,918,608
# 7       New Jersey        184,139  211,149  245,562    277,575    320,823
# 8     Pennsylvania        434,373  602,365  810,091  1,049,458  1,348,233
# 9             Ohio            NaN   45,365  230,760    581,434    937,903
# 10         Indiana            NaN    5,641   24,520    147,178    343,031
# 21        Delaware         59,096   64,273   72,674     72,749     76,748
# ...

# %%
early = early.reset_index()

# %%
early
# Out:
#     index          region           1790     1800     1810       1820  \
# 0       0           Maine         96,540  151,719  228,705    298,335
# 1       1   New Hampshire        141,885  183,858  214,460    244,161
# 2       2         Vermont         85,425  154,465  217,895    235,981
# 3       3   Massachusetts        378,787  422,845  472,040    523,287
# 4       4    Rhode Island         68,825   69,122   76,931     83,059
# 5       5     Connecticut        237,946  251,002  261,942    275,248
# 6       6        New York        340,120  589,051  959,049  1,372,812
# 7       7      New Jersey        184,139  211,149  245,562    277,575
# 8       8    Pennsylvania        434,373  602,365  810,091  1,049,458
# 9       9            Ohio            NaN   45,365  230,760    581,434
# 10     10         Indiana            NaN    5,641   24,520    147,178
# 11     21        Delaware         59,096   64,273   72,674     72,749
# ...

# %%
early = early.drop(['index'], axis=1)

# %%
early.to_csv("first_six_decades.csv")

# %%
turn_of_century = tall[53:54]

# %%
turn_of_century['region'] = 'region'

# %%
turn_of_century
# Out:
#     region  1790  1800  1810  1820  1830  1840  1850
# 55  region  1860  1870  1880  1890  1900  1910  1920
#
# [1 rows x 8 columns]

# %%
previctorian = tall[56:108]

# %%
len(tall['region'][56:108])
# Out:
# 52

# %%
previctorian.columns = turn_of_century

# %%
previctorian = previctorian.reset_index()

# %%
previctorian = previctorian.drop(['index'], axis=1)

# %%
previctorian = previctorian[0:28]

# %%
previctorian
# Out:
#             region           1790       1800       1810       1820       1830  \
# 0          Vermont        315,098    330,551    332,286    332,422    343,641
# 1    Massachusetts      1,231,066  1,457,351  1,783,085  2,238,947  2,805,346
# 2     Rhode Island        174,620    217,353    276,531    345,506    428,556
# 3      Connecticut        460,147    537,454    622,700    746,258    908,420
# 4         New York      3,880,735  4,382,759  5,082,871  6,003,174  7,268,894
# 5       New Jersey        672,035    906,096  1,131,116  1,444,933  1,883,669
# 6     Pennsylvania      2,906,215  3,521,951  4,282,891  5,258,113  6,302,115
# 7             Ohio      2,339,511  2,665,260  3,198,062  3,672,329  4,157,545
# 8          Indiana      1,350,428  1,680,637  1,978,301  2,192,404  2,516,462
# 9         Illinois      1,711,951  2,539,891  3,077,871  3,826,352  4,821,550
# 10        Michigan        749,113  1,184,059  1,636,937  2,093,890  2,420,982
# ...

# %%
previctorian.to_csv("previctorian.csv")

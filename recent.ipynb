# %%
import pandas

# %%
recent = pandas.read_csv("recent_draft.csv", index_col=0)

# %%
recent.head()
# Out:
#           region       1930       1940       1950       1960       1970  \
# 0          Maine    797,423    847,226    913,774    969,265    993,722
# 1  New Hampshire    465,293    491,524    533,242    606,921    737,681
# 2        Vermont    359,611    359,231    377,747    389,881    444,732
# 3  Massachusetts  4,249,614  4,316,721  4,690,514  5,148,578  5,689,170
# 4   Rhode Island    687,497    713,346    791,896    859,488    949,723
#
#         1980       1990
# 0  1,124,660  1,227,928
# 1    920,610  1,109,252
# 2    511,456    562,758
# 3  5,737,037  6,016,425
# 4    947,154  1,003,464
#
# [5 rows x 8 columns]

# %%
recent = recent.drop(recent.index[[30,31]])

# %%
recent[29:35]
# Out:
#          region       1930       1940       1950       1960       1970  \
# 29      Florida  1,468,211  1,897,414  2,771,305  4,951,560  6,791,418
# 32     Kentucky  2,614,589  2,845,627  2,944,806  3,038,156  3,220,711
# 33    Tennessee  2,616,556  2,915,841  3,291,718  3,567,089  3,926,018
# 34      Alabama  2,646,248  2,832,961  3,061,743  3,266,740  3,444,354
# 35  Mississippi  2,009,821  2,183,796  2,178,914  2,178,141  2,216,994
# 36     Arkansas  1,854,482  1,949,387  1,909,511  1,786,272  1,923,322
#
#          1980        1990
# 29  9,746,324  12,937,926
# 32  3,660,777   3,685,296
# 33  4,591,120   4,877,185
# 34  3,893,888   4,040,587
# 35  2,520,638   2,573,216
# 36  2,286,435   2,350,725
#
# [6 rows x 8 columns]

# %%
recent=recent.reset_index(drop=True)

# %%
recent.to_csv("recent.csv")

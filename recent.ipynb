# %%
import pandas

# %%
recent = pandas.read_csv("recent_draft.csv", index_col=0)

# %%
recent.head()
# Out:
#         region             1930             1940          1950        1960  \
# 0      Georgia        2,908,506        3,123,723     3,444,578   3,943,116
# 1      Florida        1,468,211        1,897,414     2,771,305   4,951,560
# 2  Table 1 . U  nited States Re  sident Populati  on by State:  1930 - 199
# 3       region             1930             1940          1950        1960
# 4     Kentucky        2,614,589        2,845,627     2,944,806   3,038,156
#
#         1970       1980        1990
# 0  4,587,930  5,463,105   6,478,216
# 1  6,791,418  9,746,324  12,937,926
# 2          0        NaN     (cont.)
# 3       1970       1980        1990
# 4  3,220,711  3,660,777   3,685,296
#
# [5 rows x 8 columns]

# %%
recent = recent.drop(recent.index[[0,1,2,3]])

# %%
recent.head()
# Out:
#         region       1930       1940       1950       1960       1970  \
# 4     Kentucky  2,614,589  2,845,627  2,944,806  3,038,156  3,220,711
# 5    Tennessee  2,616,556  2,915,841  3,291,718  3,567,089  3,926,018
# 6      Alabama  2,646,248  2,832,961  3,061,743  3,266,740  3,444,354
# 7  Mississippi  2,009,821  2,183,796  2,178,914  2,178,141  2,216,994
# 8     Arkansas  1,854,482  1,949,387  1,909,511  1,786,272  1,923,322
#
#         1980       1990
# 4  3,660,777  3,685,296
# 5  4,591,120  4,877,185
# 6  3,893,888  4,040,587
# 7  2,520,638  2,573,216
# 8  2,286,435  2,350,725
#
# [5 rows x 8 columns]

# %%
recent = recent.reset_index(drop=True)

# %%
recent
# Out:
#          region       1930           1940           1950       1960  \
# 0      Kentucky  2,614,589      2,845,627      2,944,806  3,038,156
# 1     Tennessee  2,616,556      2,915,841      3,291,718  3,567,089
# 2       Alabama  2,646,248      2,832,961      3,061,743  3,266,740
# 3   Mississippi  2,009,821      2,183,796      2,178,914  2,178,141
# 4      Arkansas  1,854,482      1,949,387      1,909,511  1,786,272
# 5     Louisiana  2,101,593      2,363,880      2,683,516  3,257,022
# 6      Oklahoma  2,396,040      2,336,434      2,233,351  2,328,284
# 7         Texas  5,824,715      6,414,824      7,711,194  9,579,677
# 8       Montana    537,606        559,456        591,024    674,767
# 9         Idaho    445,032        524,873        588,637    667,191
# 10      Wyoming    225,565        250,742        290,529    330,066
# 11     Colorado  1,035,791      1,123,296      1,325,089  1,753,947
# 12   New Mexico    423,317        531,818        681,187    951,023
# ...

# %%
recent.to
